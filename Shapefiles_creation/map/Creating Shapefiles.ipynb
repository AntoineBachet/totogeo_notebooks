# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
tqdm.pandas()

import geopandas as gpd
import shapely 
import fiona
import shapefile as sf

# %% [markdown]
# ### Visualization: structure of a shapefile - the biomes shapefile

# %%
dir_ = '/tf/Team 6 - Project/Finding_the_Biomes/Biomes'
biomes = fiona.open(dir_ + '/Ecoregions2017.shp')
biomes.schema

import geopandas as gpd
shape = gpd.read_file(dir_ + '/Ecoregions2017.shp')
shape.plot()

# %%
w = shapefile.Writer('shapefiles/test/testfile')
w.field('name', 'C')

w.point(122, 37) 
w.record('point1')

w.close()
